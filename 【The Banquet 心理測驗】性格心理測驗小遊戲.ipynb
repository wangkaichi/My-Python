# %%
#【The Banquet 心理測驗】性格心理測驗小遊戲
#使用物件導向class、def函數、if條件判斷、random函數
#依據玩家選擇進行分數加總，判斷不同結局

import random
class the_banquet:

    #根據favor，進行結局判斷
    def __init__(self, name, score):
        self.name = name
        self.score = score

    def get_info(self):
        print("你的名字：%s" %self.name)
        print(end="\n")

    #故事開始
    def question_one(self):
        print("【前情提要】")
        print("連續工作幾天，今天好不容易休假一天。\
        \n雖然是休假，但你仍然帶了尚未處理完的文件在家工作，想最大限度的利用時間。\
        \n幾個小時過去，你終於只剩下最後一點點就能完成，\
        \n此時你伸了一個懶腰，忽然瞥見旁邊小茶几上放著一張邀請函，\
        \n你才猛然想起前幾天收到R市的宴會邀請，時間就在今天晚上。")
        print(end="\n")
        print("【測驗開始】")
        print("【第一題】")
        print("R市，一年一度的宴會，你非常榮幸的被邀請參加。")
        print("你覺得你是因為什麼身分而被邀請參加呢？\
        \n 1. 某公司的高層。\
        \n 2. 某集團的富二代。\
        \n 3. 熱心助人的普通市民。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "某公司的高層" or s == "高層":
            self.score += 15
        elif s == "2" or s == "某集團的富二代" or s == "富二代":
            self.score += 10
        elif s == "3" or s == "熱心助人的普通市民" or s == "普通市民":
            self.score += 5
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_one()  

    def question_two(self):
        print("【第二題】")
        print("你知道這是一個高級宴會，想著要穿什麼衣服赴宴。")
        print("你覺得你會穿什麼衣服赴宴呢？\
        \n 1. 從頭到腳全套標準正裝。\
        \n 2. 有自我風格的特別裝扮。\
        \n 3. 穿平常會穿的普通衣服。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s =="從頭到腳全套標準正裝" or s =="標準正裝":
            self.score += 15
        elif s == "2" or s =="有自我風格的特別裝扮" or s =="特別裝扮":
            self.score += 10
        elif s == "3" or s =="穿平常會穿的普通衣服" or s =="普通衣服":
            self.score += 5
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_two()  

    def question_three(self):
        print("【第三題】")
        print("抵達現場，你看見長長的桌上擺滿山珍海味，此時你有些餓了。")
        print("你覺得你會從什麼東西開始吃呢？\
        \n 1. 先吃海鮮。\
        \n 2. 先吃甜點。\
        \n 3. 先拿酒水，")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "先吃海鮮" or s == "海鮮":
            self.score += 10
        elif s == "2" or s == "先吃甜點" or s == "甜點":
            self.score += 5
        elif s == "3" or s == "先拿酒水" or s == "酒水" or s == "酒":
            self.score += 15
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_three()  

    def question_four(self):
        print("【第四題】")
        print("你吃到一半，忽然台上主持人拿起麥克風，開始和大家互動。")
        print("你覺得主持人要大家做什麼呢？\
        \n 1. 玩交換名片的團康活動。\
        \n 2. 進行頒獎典禮。\
        \n 3. 放下音樂開始跳交際舞。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "玩交換名片的團康活動" or s == "團康活動":
            self.score += 15
        elif s == "2" or s == "進行頒獎典禮" or s == "頒獎典禮":
            self.score += 5
        elif s == "3" or s == "放下音樂開始跳交際舞" or s == "跳舞":
            self.score += 10
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_four()  

    def question_five(self):
        print("【第五題】")
        print("主持人促使著活動進行，鼓舞所有人下場參加接下來的活動，許多人也躍躍欲試。")
        print("你要不要加入大家呢？\
        \n 1. 來都來了，還是跟大家一起玩吧。\
        \n 2. 社交恐懼，還是默默在一旁看大家玩就好。\
        \n 3. 完全沒興趣，還是去吃東西實在。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "來都來了，還是跟大家一起玩吧":
            self.score += 10
        elif s == "2" or s == "社交恐懼，還是默默在一旁看大家玩就好":
            self.score += 15
        elif s == "3" or s == "完全沒興趣，還是去吃東西實在":
            self.score += 5
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_five()

    def question_six(self):
        print("【第六題】")
        print("宴會進行到後半段，這時忽然有人叫了你的名字，你回頭一看。")
        print("你覺得叫你的人會是誰呢？\
        \n 1. 認識多年的親梅竹馬。\
        \n 2. 不久前在工作上認識的合作方。\
        \n 3. 多年不見的高中同學。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "認識多年的親梅竹馬" or s == "親梅竹馬":
            self.score += 10
        elif s == "2" or s == "不久前在工作上認識的合作方" or s == "合作方":
            self.score += 5
        elif s == "3" or s == "多年不見的高中同學" or s == "高中同學":
            self.score += 15
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_six()  

    def question_seven(self):
        print("【第七題】")
        print("在宴會氣氛的渲染之下，你與他相談甚歡，話題最後他對你說：")
        print("你覺得他會跟你說什麼呢？\
        \n 1. 很高興見到你，希望之後還有機會再見面。\
        \n 2. 宴會結束後還有續攤，他邀請你一起參加聚會。\
        \n 3. 問你宴會結束後還有沒有事，沒事的話約你去他家喝茶。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "很高興見到你，希望之後還有機會再見面":
            self.score += 10
        elif s == "2" or s == "宴會結束後還有續攤，他邀請你一起參加聚會":
            self.score += 15
        elif s == "3" or s == "問你宴會結束後還有沒有事，沒事的話約你去他家喝茶":
            self.score += 5
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_seven()  

    def question_eight(self):
        print("【第八題】")
        print("你還沒回答他，忽然有人喊了他的名字，他匆匆離開，丟下你一個人。")
        print("你現在要做什麼呢？\
        \n 1. 去看看還有沒有活動，如果沒有的話就離開宴會。\
        \n 2. 去看看還有沒有食物，如果沒有的話就離開宴會。\
        \n 3. 四處看看還有沒有認識的人，如果沒有的話就離開宴會。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "去看看還有沒有活動，如果沒有的話就離開宴會":
            self.score += 5
        elif s == "2" or s == "去看看還有沒有食物，如果沒有的話就離開宴會":
            self.score += 15
        elif s == "3" or s == "四處看看還有沒有認識的人，如果沒有的話就離開宴會":
            self.score += 10
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_eight()  

    def question_nine(self):
        print("【第九題】")
        print("在宴會上你吃飽喝足，眼看沒什麼事，你離開現場走到門口。")
        print("你要怎麼回家呢？\
        \n 1. 因為喝了酒，所以叫計程車回家。\
        \n 2. 反正家離這裡不遠，索性用走路的回家。\
        \n 3. 打電話叫人來接你回家。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "因為喝了酒，所以叫計程車回家" or s == "計程車":
            self.score += 15
        elif s == "2" or s == "反正家離這裡不遠，索性用走路的回家" or s == "走路":
            self.score += 5
        elif s == "3" or s == "打電話叫人來接你回家" or s == "打電話":
            self.score += 10
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_nine()
            
    def question_ten(self):
        print("【第十題】")
        print("你回到家，整晚的社交與宴會活動讓你身心疲憊，只想趕快休息。")
        print("你回到家後要做的第一件事情是什麼呢？\
        \n 1. 什麼也不管，趕快洗澡，早點休息。\
        \n 2. 想起還有工作還沒做完，趕緊利用時間將剩下的工作補齊。\
        \n 3. 傳訊息給剛才宴會上遇見的那人，跟他說你先離開了。")
        s = input("回答：")
        print(end="\n")
        if s == "1" or s == "什麼也不管，趕快洗澡，早點休息":
            self.score += 5
        elif s == "2" or s == "想起還有工作還沒做完，趕緊利用時間將剩下的工作補齊":
            self.score += 15
        elif s == "3" or s == "傳訊息給剛才宴會上遇見的那人，跟他說你先離開了":
            self.score += 10
        else:
            print("<你的選擇無法辨識，請重新選擇>")
            print(end="\n")
            player.question_ten()

    #進行判斷
    def destiny(self):
        if self.score < 81:
            print("【正在生成測驗結果】")
            print(end="\n")
            print("【%s的性格為：溫柔堅忍的最佳輔助】" % self.name)
            print(end="\n")
            print("你表面或許剛強，但其實內心有非常柔軟的一面，\
            \n是一個能夠體貼他人的個性，並擁有極強的忍耐力，\
            \n能在困境當中隨風折腰，風過而挺立，無所畏懼。\
            \n你有著想要力爭上游的心，但卻常常因為內心的藝術氣質而太過重視休閒娛樂，\
            \n導致容易失敗，並不適合擔任指揮做事的領導角色。\
            \n但因為你的個性從容隨和，因此非常適合擔任他人的最佳謀士，\
            \n能夠很有創意的提出有趣想法，給予他人很不錯的意見。")
            print(end="\n")
            print("【%s的感情觀】" % self.name)
            print(end="\n")
            print("喜歡由他人主動，一見鍾情的機率很高。\
            \n表面上純純的愛戀，實則佔有慾強，慎防妒忌，需提高自信心。")
            print(end="\n")
            print("【%s的幸運數字】" % self.name)
            print(end="\n")
            num = random.randint(1,100)
            print(num)
        elif self.score < 101:
            print("【正在生成測驗結果】")
            print(end="\n")
            print("【%s的性格為：自尊心強的前排勇士】" % self.name)
            print(end="\n")
            print("你或許表面給人一種與世無爭的柔弱感，但其實內心剛強，極度重視自尊心，愛面子。\
            \n你非常注重外表的體面與否，願意花錢裝扮自己只為了給他人良好印象，而你也樂在其中，\
            \n你是一個做事非常踏實的人，或許表面上偶爾看似輕浮，實則不容易受他人影響，較堅持己見，\
            \n內心有自己的一套為人處事標準，因此容易被認為固執，\
            \n但只要將固執用在對的地方，全心全意投入想追求的事物上，必有所成。")
            print(end="\n")
            print("【%s的感情觀】" % self.name)
            print(end="\n")
            print("外表看似花心，實則非常忠於感情。\
            \n在感情中容易陷入自我中心，不會細心考慮對方的感受，需多加注意。")
            print(end="\n")
            print("【%s的幸運數字】" % self.name)
            print(end="\n")
            num = random.randint(1,100)
            print(num)
        elif self.score < 111:
            print("【正在生成測驗結果】")
            print(end="\n")
            print("【%s的性格為：察言觀色的遠程射手】" % self.name)
            print(end="\n")
            
            print("你擁有一個容易吸引他人注意的性格，擁有很強的社交手腕，察言觀色能力極強，\
            \n善於判斷一切狀況，並且懂得讓自己隨著環境改變，輕易就能融入人群之中。\
            \n外顯性格較為豪放不拘，你非常喜愛自由，不喜愛被拘束，若沒把握好分寸，\
            \n容易會被認為自以為是，只以自己的自由為優先考量，需特別注意。\
            \n你並不適合被侷限在框架之中，激烈多變的人生是你的畢生追求，\
            \n如此才能將你的聰明才智充分發揮，成為一個懂得靈機應變的高手。")
            print(end="\n")
            print("【%s的感情觀】" % self.name)
            print(end="\n")
            print("感情觀豪放，喜愛自由，容易移情別戀。\
            \n除非他人猛烈追求，否則不太會主動追求異性，很難安定專一，需特別注意。")
            print(end="\n")
            print("【%s的幸運數字】" % self.name)
            print(end="\n")
            num = random.randint(1,100)
            print(num)
        elif self.score < 121:
            print("【正在生成測驗結果】")
            print(end="\n")
            print("【%s的性格為：意志堅定的堅硬護盾】" % self.name)
            print(end="\n")
            print("你擁有一個不服輸的個性，認定的事情就會堅持到底，做事乾淨俐落不拖泥帶水，\
            \n雖然有些頑固不知變通，卻也因為這樣反而能貫徹始終，完成旁人無法完成的大事。\
            \n你的頭腦非常清楚，靈活又擅長分析，凡事都能計算的非常精準，\
            \n在你所專業的領域之上，能掌握住所有對你有最佳利益的狀況，一展長才獲利滿滿。")
            print(end="\n")
            print("【%s的感情觀】" % self.name)
            print(end="\n")
            print("感情上較容易自我中心思考，忘記考慮對方的感受，感情難以長久。\
            \n若是不愛對方了也會立刻一刀兩斷，屬於絕不浪費時間拖泥帶水的感情觀。")
            print(end="\n")
            print("【%s的幸運數字】" % self.name)
            print(end="\n")
            num = random.randint(1,100)
            print(num)
        elif self.score < 151:
            print("【正在生成測驗結果】")
            print(end="\n")
            print("【%s的性格為：穩重踏實的群攻戰士】" % self.name)
            print(end="\n")
            print("你是一個做任何事都腳踏實地的人，既專注又執著，穩穩健健的完成自己所設定的每個目標。\
            \n你做事絕不草率，在任何事情上都能給人安心感，因此容易獲得他人的信任。\
            \n善於做計劃的你，意志堅韌、刻苦耐勞，無論做什麼事情都容易成功，\
            \n只是因為貫徹始終的頑固個性讓你有些不知變通，缺乏靈機應變的能力，因此容易得罪人。")
            print(end="\n")
            print("【%s的感情觀】" % self.name)
            print(end="\n")
            print("容易獲得異性好感，因此異性緣極佳。\
            \n非常重視儀式感與氣氛，戀愛中能給對方強烈的激情與信賴。")
            print(end="\n")
            print("【%s的幸運數字】" % self.name)
            print(end="\n")
            num = random.randint(1,100)
            print(num)


#執行
print("<歡迎來到 The Banquet 心理測驗遊戲>\
\n快來測測看你是什麼性格吧！(共十題)")
print(end="\n")
player = input("請輸入你的名字：")
print(end="\n")
player = the_banquet(player,0)

player.get_info()
player.question_one()
player.question_two()
player.question_three()
player.question_four()
player.question_five()
player.question_six() 
player.question_seven() 
player.question_eight() 
player.question_nine() 
player.question_ten() 
player.destiny()
