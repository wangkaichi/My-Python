# %%
#【secret_date攻略遊戲】劇情互動小遊戲
#使用物件導向class與def函數
#依據玩家輸入不同的選項，走向不同故事線
#前導分支*3
#主線分支*4
#結局分支*4 

class secret_date:

    #根據favor，進行好壞結局的判斷
    def __init__(self, name, favor):
        self.name = name
        self.favor = favor

    #設定閱讀分隔鍵，類似遊戲閱讀點擊空白處的功能
    def space(slef):
        print(end="\n")
        input()

    #故事開始
    def start(self):
        print("夜晚。")
        A.space()
        print("「呼……」你獨自一人坐在電腦前，長呼出一口氣。\
        \n移開因為盯著螢幕太久而酸澀的眼睛，半靠在椅子上，\
        \n抬起手臂遮住眼睛，略擋住頭頂炙熱的日光燈。")
        A.space()
        print("「好累啊……」你工作一整天，看著python上密密麻麻的coding，\
        \n雖然你是靠這項能力在業界混口飯吃，但整天與電腦為伍，偶爾也讓你覺得疲累。")
        A.space()
        print("「天天這樣熬夜，身體吃不消啊……」你保持著半躺在椅子上的姿勢，假寐休息。\
        \n這些有著嘆息的話語，迴盪在房間中，只有你自己一個人聽見。\
        \n無人與你分擔疲累。")
        A.space()
        print("反正也已經習慣了。")
        A.space()
        print("休息了一陣子，你緩緩移開手臂，卻被燈光刺到而瞇了瞇眼。\
        \n重新適應光線後，你重新將視線投向面前的電腦。")
        A.space()
        print("「疑？」你看著面前的電腦螢幕中，跳出了一個奇怪的提示訊息，\
        \n你不知怎麼了，鬼使神差點了進去，發現是一個python介面。")
        A.space()
        print("「這是什麼？」你看著上面顯示著奇怪的框框，根據你的專業知識，\
        \n你知道那是input會出現的框框，但是你不知道為什麼會出現在這裡。")
        A.space()
        print("反正不是你輸入進去的。")
        A.space()
        print("你嘗試修改程式碼，卻發現無論怎麼重新Run，那個input框框仍一直存在。\
        \n發生這樣的事讓你滿頭問號，心想不過是休息一下沒看螢幕，怎麼就發生這種詭異的事？")
        A.space()
        print("你怎麼樣都無法將之關掉，這時候框框跳出了一條提示訊息：\
        \n<歡迎來到 secret date 攻略遊戲>\
        \n看起來是要指引你輸入文字進去。")
        A.space()
        print("你心中懷疑又猶豫，忌憚著這個忽然出現在自己電腦中的奇怪東西。\
        \n但其實你還是有些好奇。")
        A.space()
        print("該不該按照訊息所說的，輸入資料呢？\
        \n1：輸入什麼輸入，反手就是把電腦關機，直接休息。\
        \n2：好奇大過恐懼，照著做就是了。\
        \n3：用自己的專業知識，努力想辦法把奇怪的程式碼換掉。")
        s = input("回答：")
        A.space()
        if s == "1":
            A.START_ONE()
        elif s == "2":
            A.START_TWO()
        elif s == "3":
            A.START_THREE()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")     #設定防呆
            print(end="\n")
            A.start()

    def START_ONE(self):
        print("你根本不想理會這則奇怪的訊息。\
        \n「看了一天的電腦，現在還發生這種怪事，真煩。」你大嘆一口氣。")
        A.space()
        print("心中想著工作也差不多告一段落，\
        \n於是你隨手將所有檔案關閉，發現這個奇怪的視窗無法關閉，\
        \n但你也不管那麼多，直接強制關機，決定今天要早點睡、早點休息。")
        A.space()
        print("於是乎你繼續日復一日的不斷工作、不斷工作，\
        \n再也沒有機會發現奇怪訊息中藏著的秘密。")
        A.space()
        print("也沒辦法再次遇見念念不忘的那個他 -- %s" %self.name)
        A.space()
        print("<遊戲結束，重新開始>")
        A.space()
        A.start()

    def START_TWO(self):
        print("你還是決定按照奇怪的提示輸入文字。\
        \n輸入完畢後，你看見框框消失，出現了一段新的文字故事：")
        A.space()
        print("「喂！你等等我呀！」%s從後面朝你跑過來，你停下腳步，回頭看他。\
        \n「呼呼呼……你別走那麼快……」他追上你，在你面前彎腰喘了幾口氣，邊喘邊說。" %self.name)
        A.space()
        print("你沒有回應他，只是看著他，直到他緩了過來，先對你開口。\
        \n「你、你還沒有給我答覆……」他雖然不喘，但語氣有些扭捏。")
        A.space()
        print("「什麼答覆？」你不明白他在說什麼，你與他之間，什麼時候有過需要'答覆'的事情？\
        \n「你……」他有些震驚，雙眼圓睜，說不出話。")
        A.space()
        print("奇怪，他到底在說什麼，怎麼會一副對你的回答感到難以置信的表情？你心裡想。\
        \n%s對你的反應只震驚了一瞬，後來他似乎想起了什麼，震驚的表情收起，忽然掛上了笑容。" %self.name)
        A.space()
        print("「！」看見這個笑容，你心臟一跳。")
        A.space()
        print("似乎在哪裡見過。\
        \n可是你卻想不起來。")
        A.space()
        print("看見你愣了片刻，他似乎更有信心，笑容又更深了些許。\
        \n你只看見他輕啟那對薄唇，緩緩開口：")
        A.space()
        print("「我說我喜歡你，你喜歡我嗎？」你聽見他這麼說。")
        A.space()
        print("不知為何，他說出這種話，本該令你感到震驚，可是此時此刻你卻覺得熟悉，\
        \n甚至有種本來就應該如此的錯覺。")
        A.space()
        print("沒得到你的回應，他又朝你靠近了一步，更是近在咫尺。")
        A.space()
        print("「我說我喜歡你，你喜歡我嗎？」他靠你極近，又問了一次，要你給予回覆。")
        A.space()
        print("你想要怎麼回覆他呢？\
        \n1：我不喜歡你。\
        \n2：我喜歡你。\
        \n3：我、我不知道，我連你是誰都想不起來，怎麼知道自己喜不喜歡你？")
        s = input("回答：")
        A.space()
        if s == "1":
            A.START_TWO_ONE()
        elif s == "2":
            A.START_TWO_TWO()
        elif s == "3":
            A.START_TWO_THREE()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
            print(end="\n")
            A.START_TWO()

    def START_THREE(self):
        print("這種小問題怎麼難得倒我？")
        A.space()
        print("從業多年，debug已經是你信手捻來的事情，\
        \n面對挑戰你躍躍欲試，不可能輕言放棄。")
        A.space()
        print("於是你花了很多時間，用了各種方法卻還是行不通，\
        \n連簡單粗暴地將程式關掉重開都無法解決這奇怪的訊息。\
        \n就在你快要沒有耐心之時，電腦又跳出了訊息。")
        A.space()
        print("原來是要你重新再做一次選擇……")
        A.space()
        print("請再次輸入你的選擇：\
        \n1：輸入什麼輸入，反手就是直接把電腦關機，直接休息。\
        \n2：好奇大過恐懼，照著做就是了。")
        s = input("回答：")
        A.space()
        if s == "1":
            A.START_THREE_ONE()
        elif s == "2":
            A.START_THREE_TWO()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
            print(end="\n")
            A.START_THREE()

    def START_TWO_ONE(self):
        print("「我不喜歡你。」")
        A.space()
        print("你這麼說，換來了%s的震驚。\
        \n「你說什麼？」他不敢置信你會說出這樣的話，又問了一次。" %self.name)
        A.space()
        print("「你為什麼要問我這種問題？」你有些不高興。「我不認識你，一見面你就說喜歡我，誰都會嚇到吧？」\
        \n你不理智的生著氣，忘記這一切的發生本身就存在著不合理。\
        \n當你被追著停下腳步時，這些不合理都早已刻進你的魂魄中，\
        \n但你現在卻硬生生地想要逃離。")
        A.space()
        print("瞬間，你眼前的他逐漸扭曲，而你也頭痛欲裂。")
        A.space()
        print("「這到底是怎麼回事？你是誰？你想對我做什麼？」抱著頭，慌亂之下你看向眼前的他，只覺得他離你好遠好遠。\
        \n不知暈眩了多久，你才聽見他的聲音從很遠的地方傳來。")
        A.space()
        print("「你選錯了。」這些話迴盪在空氣中，而你一句話也說不出口。")
        A.space()
        print("「你說過無論如何都會愛我，甚至可以為我生、為我死。」\
        \n「你說無論時空與距離，只要有我在，你就一定會愛上我。」\
        \n「你說……」他停頓，笑了。")
        A.space()
        print("「呵，你對我說了這麼多，但你卻在第一步就踏錯了，真是可笑。」")
        A.space()
        print("聽著他的話語，你腦中似乎有什麼要破土而出，\
        \n你想要開口，可眼前的他卻忽然湊近，伸手掐住你的脖頸。")
        A.space()
        print("「呃！」你無法呼吸，模糊的視線中是他瘋狂的笑容，\
        \n以及滑落眼角的淚。")
        A.space()
        print("「再也沒有機會了。」他的手逐漸收緊，你的意識也漸漸抽離。")
        A.space()
        print("「你和我之間，再也沒有機會了。」")
        A.space()
        print("在大腦缺氧失去知覺的前一刻，那張痛苦與瘋狂的臉龐深深烙印在你的眼眸，\
        \n與破土而出的記憶混雜。")
        A.space()
        print("%s。\
        \n這是最後跳進你腦中的名字，接著襲捲你的便是黑暗的死亡。" %self.name)
        A.space()
        print("你終究是來不及。")
        A.space()
        print("<遊戲結束，重新開始>")
        A.space()
        A.start()

    def START_TWO_TWO(self):
        print("「我喜歡你。」")
        A.space()
        print("你這麼說，得到了他意外的眼神。\
        \n「怎麼了嗎？」他沒說話，你又問了一次。")
        A.space()
        print("「不……沒事，我只是沒想到你會說得這麼直接。」他輕笑一聲，回答你的問題。")
        A.space()
        print("「其實我也不確定這樣回答對不對，只是直覺告訴我應該喜歡你。」\
        \n你想不起他是誰，自然對他也不會有喜歡的情緒，\
        \n只是直覺告訴你這個回答會影響你和他之間的關係，\
        \n而他似乎是你很重要的人。")
        A.space()
        print("「應該喜歡我？」他愣愣的重複你的話，似有不解。\
        \n「嗯。」你不知道該怎麼解釋，只能實話實說。\
        \n「我不知道自己是誰，自然也不記得你是誰，但是直覺告訴我既然出現在這裡，表示你很重要。」")
        A.space()
        print("「我很重要……」不知為何他陷在你直白地訴說中遲遲沒有緩過來，你也不急，等待著他。")
        A.space()
        print("「罷了……」許久，他回過神，紅著臉輕笑出了聲。「這種話你也沒少對我說過，我卻到現在還不習慣。」\
        \n你心中不解他說的話是何意，也不明白自己是何時對他說過哪種話，\
        \n不過他既然說有，那就有吧。")
        A.space()
        print("他笑著將手覆上你的臉頰，觸及微涼，你忍不住哆嗦了一下，\
        \n下意識地配合他的動作，聽見他繼續說道：\
        \n「告訴我，你還記得些什麼？」")
        A.space()
        print("這句話似乎帶你去了很遠的地方，你的思緒被牽引著，越過了一望無際的黑暗，\
        \n忽然之間找到一束亮光，很微弱、很微弱，但你看見了一點點的縫隙。\
        \n在窺見光明的前一刻，你聽見他細聲喃喃一句：")
        A.space()
        print("「這次就不必經歷生死了，這是對你直白的獎勵。」")
        A.space()
        print("「在縫隙中你看見了……\
        \n1：一間咖啡廳、咖啡、彩色的靈魂。\
        \n2：一間酒吧、調酒、微醺的霜落。")
        s = input("回答：")
        A.space()
        if s == "1":
            A.question_one()
        elif s == "2":
            A.question_two()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
            print(end="\n")
            A.START_TWO_TWO()

    def START_TWO_THREE(self):
        print("「我、我不知道，我連你是誰都想不起來，怎麼知道自己喜不喜歡你？」")
        A.space()
        print("你很想給他回應。\
        \n他靠近時的熟悉感，讓你不知所措，\
        \n你有一種感覺，是你本應該要記起的東西，可是你卻忘了。")
        A.space()
        print("你有些懊惱也有些恐懼，而他只是笑盈盈地望著你。\
        \n「沒關係的。」他說。\
        \n「你不記得我，很正常。」他安撫你。「因為你連你自己是誰都忘了，對嗎？」")
        A.space()
        print("聽他這麼說，你才忽然意識到，你確實連自己叫什麼名字都忘了。\
        \n你的表情十分精彩，他不需等你開口，便知道答案。")
        A.space()
        print("「呵……」他輕笑一聲，抬起手撫上你的臉頰。\
        \n「不要害怕，我會幫你的。」他的聲音有種安定人心的力量，你一下子便平靜下來，只是盯著他的眼神從未離開。")
        A.space()
        print("指腹在臉頰上緩緩摸索，他臉上的笑容未曾消失，繼續說道：\
        \n「我會幫你的，但你要先告訴我，你還記得些什麼？」")
        A.space()
        print("他的聲音似乎帶你去了很遠的地方，你的思緒被牽引著，越過了一望無際的黑暗，\
        \n忽然之間找到一束亮光，很微弱、很微弱，但你看見了一點點的縫隙。")
        A.space()
        print("「在縫隙中你看見了……\
        \n1：一片海、雨夜、苦澀的噩夢。\
        \n2：高樓、強風、勇敢的意義。")
        s = input("回答：")
        A.space()
        if s == "1":
            A.question_three()
        elif s == "2":
            A.question_four()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
            print(end="\n")
            A.START_TWO_THREE()

    def START_THREE_ONE(self):
        print("「這是強迫我一定要選另外兩個選項嗎……」你感到無言，\
        \n對於系統出現如此荒謬的設定百思不解。")
        A.space()
        print("雖然心中隱隱有種預感，系統一定希望自己選2，\
        \n但是反骨如你，決心不被奇怪訊息牽著鼻子走，\
        \n於是還是選擇直接把電腦關掉，心想只要沒看見，就當作無事發生。")
        A.space()
        print("「哎呀……真是疲憊。」你將電腦闔上，伸了一個懶腰，\
        \n一看時間竟然已經三更半夜，再熬夜下去總有一天會禿頭的！")
        A.space()
        print("於是為了你的髮量與肝臟著想，你立刻上床睡覺，\
        \n接下來的日子你繼續日復一日的不斷工作、不斷工作，\
        \n再也沒有機會發現奇怪訊息中藏著的秘密。")
        A.space()
        print("也沒辦法再次遇見念念不忘的那個他 -- %s" %self.name)
        A.space()
        print("<遊戲結束，重新開始>")
        A.space()
        A.start()

    def START_THREE_TWO(self):
        print("「這是強迫我一定要選另外兩個選項嗎……」你感到無言，\
        \n對於系統出現如此荒謬的設定百思不解。")
        A.space()
        print("看著眼前兩個選項，你有種感覺，除了選項2以外，另外兩個都會產生一樣的結果。\
        \n既然這樣，人生就是要挑戰一下，做一些自己平常不會做的事情，\
        \n於是你毅然決然輸入了2。")
        A.space()
        print("輸入完畢，你看見框框消失，出現了一段新的文字故事：")
        A.space()
        print("「喂！你等等我呀！」%s從後面朝你跑過來，你停下腳步，回頭看他。\
        \n「呼呼呼……你別走那麼快……」他追上你，在你面前彎腰喘了幾口氣，邊喘邊說。" %self.name)
        A.space()
        print("你沒有回應他，只是看著他，直到他緩了過來，先對你開口。\
        \n「你、你還沒有給我答覆……」他雖然不喘，但語氣有些扭捏。")
        A.space()
        print("「什麼答覆？」你不明白他在說什麼，你與他之間，什麼時候有過需要'答覆'的事情？\
        \n「你……」他有些震驚，雙眼圓睜，說不出話。")
        A.space()
        print("奇怪，他到底在說什麼，怎麼會一副對你的回答感到難以置信的表情？你心裡想。\
        \n%s對你的反應只震驚了一瞬，後來他似乎想起了什麼，震驚的表情收起，忽然掛上了笑容。" %self.name)
        A.space()
        print("「！」看見這個笑容，你心臟一跳。")
        A.space()
        print("似乎在哪裡見過。\
        \n可是你卻想不起來。")
        A.space()
        print("看見你愣了片刻，他似乎更有信心，笑容又更深了些許。\
        \n你只看見他輕啟那對薄唇，緩緩開口：")
        A.space()
        print("「我說我喜歡你，你喜歡我嗎？」你聽見他這麼說。")
        A.space()
        print("不知為何，他說出這種話，本該令你感到震驚，可是此時此刻你卻覺得熟悉，\
        \n甚至有種本來就應該如此的錯覺。")
        A.space()
        print("沒得到你的回應，他又朝你靠近了一步，更是近在咫尺。")
        A.space()
        print("「我說我喜歡你，你喜歡我嗎？」他靠你極近，又問了一次，要你給予回覆。")
        A.space()
        print("你想要怎麼回覆他呢？\
        \n1：我不喜歡你。\
        \n2：我喜歡你。\
        \n3：我、我不知道，我連你是誰都想不起來，怎麼知道自己喜不喜歡你？")
        s = input("回答：")
        A.space()
        if s == "1":
            A.START_TWO_ONE()
        elif s == "2":
            A.START_TWO_TWO()
        elif s == "3":
            A.START_TWO_THREE()
        else:
            print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
            print(end="\n")
            A.START_THREE_TWO()

    def question_one(self):
        print("【觸發主線一：彩色的咖啡靈魂】")
        print(end="\n")
        print("清晨的咖啡廳。")
        A.space()
        print("環境呈現著寧靜色調，復古的桌椅顏色相襯，\
        \n與左側整面擺滿書的書架完美契合。")
        A.space()
        print("吧檯處擺著各種沖泡咖啡的器具：\
        \n手沖、蒸餾、義式咖啡機，而吧檯旁的玻璃櫃裡點著白光，放著各式甜點，格外誘人。")
        A.space()
        print("此時%s就在這樣的一間咖啡廳裡，看著自己親手沖泡出的咖啡，滿意的深吸一口氣。\
        \n咖啡香融入在空氣中，微苦、微酸，像是人生一般。" %self.name)
        A.space()
        print("「你來了啊。」\
        \n你一進門，看見如此寧靜的畫面，心中微動。\
        \n他聽見門上鈴鐺響聲，撇了你一眼，輕聲說道。")
        A.space()
        print("「嗯，你在做什麼？」你朝他走近，邊問道。\
        \n「我在品嘗咖啡的顏色。」他聞了聞咖啡杯中的香氣，回答你。")
        A.space()
        print("「咖啡的顏色？」你不解，咖啡的顏色要如何品嘗呢？\
        \n「嗯，咖啡的顏色。」")
        A.space()
        print("他品了口咖啡，習慣了好咖啡才有的獨特果酸，\
        \n入口後從舌根一點一點侵蝕味蕾，帶著些許侵略性，\
        \n但卻又溫柔至極，如此矛盾著在最後化為甘甜，\
        \n在舌苔上久久揮散不去，原本的果酸竟也讓人回味無窮。")
        A.space()
        print("你靜靜的享受這片刻安靜，等待著他的回應。\
        \n許久，他終於開口。")
        A.space()
        print("「我最喜歡喝冷藍色的咖啡。」他說道。\
        \n「這種咖啡自帶一種果酸香氣，有著桃子、蘋果的味覺體驗，\
        \n我喜歡這種在味蕾留下刺激體驗的感受。」")
        A.space()
        print("「那你還有其他喜歡的顏色嗎？」")
        A.space()
        print("「有，我還喜歡粉橘色的咖啡。這種咖啡喝起來有柑橘香氣\
        \n像是橘子、鳳梨的味道，入口回味甘甜，我也很喜歡。」")
        A.space()
        print("「那你有不喜歡的嗎？」")
        A.space()
        print("「有，我最不喜歡的就是咖啡色的咖啡。」\
        \n他笑了笑。\
        \n「很意外吧。這種咖啡喝起來就只是咖啡，沒有靈魂。」")
        A.space()
        print("他說完後，你思考著沒有接話。\
        \n見你沒說話，他又替自己沖了一杯咖啡，熱騰騰的煙往杯口冒著，\
        \n他喝了一口，笑說：「是我最喜歡的顏色。」")
        A.space()
        print("請問他最喜歡的咖啡顏色是什麼顏色？(請輸入文字)")
        s = input("回答：")
        if s == "冷藍色" or s == "冷藍":
            self.favor += 40
            print(end="\n")
            print("<被%s喜歡，好感度增加>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()
        else:
            self.favor -=10
            print(end="\n")
            print("<被%s厭惡，好感度減少>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()

    def question_two(self):
        print("【觸發主線二：微醺的酒意霜落】")
        print(end="\n")
        print("夜晚的酒吧。")
        A.space()
        print("面前是開放式廚房，吧台上整齊擺放著調酒器具，\
        \n波士頓雪克杯、吧叉匙、量酒器、隔冰器等等，\
        \n所有調酒器具都清洗的很乾淨，一點水漬也沒有。")
        A.space()
        print("此時%s就坐在吧檯前的高腳椅上，看著面前的你擺弄著器具，\
        \n等著你為他親手調製一杯調酒。" %self.name)
        A.space()
        print("「我都已經坐在這裡多久了，我的酒呢？」\
        \n%s單手撐著頭，慵懶地看著你，語氣中是些許的調笑，\
        \n你聽見他的聲音，心中微動。" %self.name)
        A.space()
        print("「想喝什麼？」送出手上別桌的最後一杯調酒，你終於有空閒時間看向他。\
        \n%s今天穿的很好看，這是你看到他的第一個想法。" %self.name)
        A.space()
        print("「都可以。」他說。")
        A.space()
        print("「那就先來一杯粉色佳人。」你將琴酒、檸檬汁、紅石榴糖漿以及蛋白，\
        \n依比例搖晃均勻，將漂亮的粉橙色液體在透明酒杯中緩緩注入，\
        \n杯邊因為冷飲的關係泛起一層水霧，看起來十分夢幻。")
        A.space()
        print("你夾起一旁的檸檬皮，在杯口上扭轉一圈，讓檸檬皮的香氣沾染上杯口，\
        \n隨後將扭轉過的Lemon Peel放入杯中，漂浮在白色微沫上如同雲朵中的綠芽，\
        \n顯眼卻又不會搶走風采。")
        A.space()
        print("「吶，請慢用。」你將調酒放到%s面前，他笑著看了你一眼，\
        \n拿起來喝了一口，瞬間皺了眉頭。" %self.name)
        A.space()
        print("「不喜歡。」%s這麼說，你聳聳肩。\
        \n「這杯調酒只是漂亮而已，並不好喝。」你回應他。" %self.name)
        A.space()
        print("「那你調一杯好喝的給我喝。」\
        \n你點點頭，順手清洗了器具，擦拭乾淨後，準備開始第二輪調酒。")
        A.space()
        print("你將伏特加、水蜜桃香甜酒、柳橙汁、蔓越莓汁，\
        \n稱量過倒入玻璃杯中，與上一杯同樣的做法，\
        \n在鋼杯中加入冰塊，倒入液體後扣緊搖盪至結霜。")
        A.space()
        print("%s目不轉睛地盯著你表演調酒，直到一杯酒放到他的面前" %self.name)
        A.space()
        print("「這杯叫做性感沙灘。」\
        \n你看著他拿起酒杯喝了一口，眉頭舒展開來，露出笑容。\
        \n「這杯好喝！」他說的同時又喝了兩口。")
        A.space()
        print("「因為伏特加經過活性碳蒸餾後，本身沒什味道，\
        \n再加上混合了這麼多果汁，喝起來就像是果汁一樣，\
        \n所以要小心，千萬不要因為好喝而喝醉。」")
        A.space()
        print("看見他喝得開心，你也跟著開心。")
        A.space()
        print("「這杯我真的很喜歡！」%s不斷強調著他對這杯調酒的喜愛\
        \n這也讓你十分有成就感。" %self.name)
        A.space()
        print("所以%s喜歡的調酒，是用什麼基酒調製成的？(請輸入文字)" %self.name)
        s = input("回答：")
        if s == "伏特加" or s == "伏特加酒" or s == "vodka" or s =="VODKA" or s == "Vodka":
            self.favor += 40
            print(end="\n")
            print("<被%s喜歡，好感度增加>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()
        else:
            self.favor -=10
            print(end="\n")
            print("<被%s厭惡，好感度減少>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()

    def question_three(self):
        print("【觸發主線三：雨夜的苦澀惡夢】")
        print(end="\n")
        print("雨夜。")
        A.space()
        print("橘紅色的海被染成一片黑，沒有一絲星光。")
        A.space()
        print("天空下起細細小雨，異常寒冷。\
        \n路過此地的人腳步急促，毫不停留，陰影遮住半張臉，看不清臉。")
        A.space()
        print("眺望遠方，欄杆邊站著一抹身影，融入夜色，衣角隨著風吹而晃動。")
        A.space()
        print("再往前一步，便是深海。")
        A.space()
        print("那抹人影便是%s。\
        \n你朝他走過去，卻被他說的話硬生生止住步伐。" %self.name)
        A.space()
        print("「不要過來。」\
        \n他似乎是知道你要來，又或者是聽見腳步聲，\
        \n沒有轉頭就對你這麼說。")
        A.space()
        print("「你做什麼？」\
        \n你見他又往前走了一步，心臟加速，出聲喊了他。")
        A.space()
        print("「好苦，真的好苦啊。」他側身瞥了你一眼，\
        \n你隱約看見他的眼角有眼淚滑落。\
        \n說著說著他又移動了半吋，再多移動一些，\
        \n他就要掉入海中。")
        A.space()
        print("「你、你下來！」\
        \n你慌張地喊住他。「如果覺得苦，那就努力變甜啊！」")
        A.space()
        print("「那如果我沒辦法變甜呢？」\
        \n%s完全轉過身面對你，背對著大海。\
        \n朝你露出了溫柔卻苦澀的微笑，像是訣別。" %self.name)
        A.space()
        print("「如果我真的只能往下走呢？」\
        \n你一時無法組織言語，他看著你片刻，搖了搖頭。\
        \n隨後往後跨了一步，身體跌落。")
        A.space()
        print("「等等，你回來！」\
        \n你朝他奔過去，緊緊抓住那隻跌落的手。\
        \n「我不會讓你走的。」")
        A.space()
        print("「為什麼？」\
        \n懸著，他仰起頭看你，臉上沒有表情。\
        \n「我這麼苦，有什麼值得你留戀？」")
        A.space()
        print("慌亂之間你不及思考，只能說出內心想到的話：\
        \n「苦有苦的價值，就算再苦澀的東西，也會有人喜歡的。」你說道。")
        A.space()
        print("「可是沒有人來拯救我。」")
        A.space()
        print("「為什麼一定要有人來救你？\
        \n有時候你會發現救你的人也可以是你自己啊！」你緊緊抓住他的手。")
        A.space()
        print("「更何況我現在不是抓住你了嗎？」")
        A.space()
        print("不知為何你忽然擁有了力氣，將他從深淵拉了出來，\
        \n緊緊擁抱著他。")
        A.space()
        print("「那怕有一絲絲的機會，我也希望你不要放棄。」")
        A.space()
        print("「你不該放棄你自己，而我也不會放棄你。」")
        A.space()
        print("這片海在白天是什麼顏色的？(請輸入文字)")
        s = input("回答：")
        if s == "橘紅色" or s == "橘紅":
            self.favor += 40
            print(end="\n")
            print("<被%s喜歡，好感度增加>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()
        else:
            self.favor -=10
            print(end="\n")
            print("<被%s厭惡，好感度減少>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()

    def question_four(self):
        print("【觸發主線四：生命中勇氣的意義】")
        print(end="\n")
        print("高樓。")
        A.space()
        print("高樓邊沒有護欄，地上凌亂躺著幾根斷掉的鋼筋，荒廢而淒涼，\
        \n強風冷冽的吹著，將站在高樓邊緣的那人襯得更加單薄。")
        A.space()
        print("那人便是%s。\
        \n他的手背在身後，背對著你，你朝他走近。\
        \n「你在看什麼？」你見他眺望遠方，開口詢問。" %self.name)
        A.space()
        print("「是你。」他坐下，雙腳懸空在高樓邊晃啊晃。\
        \n看見你來，指了指自己旁邊，示意你與之並肩而坐，你低下頭看他，心中微動。")
        A.space()    
        print("「你知道嗎？我有時候會覺得世界離我好遠。」你坐下後他說道。\
        \n他語氣中有著悲傷，你有些震驚，因為平時的他總是笑臉迎人，你看不出原來他也會悲傷。")
        A.space()
        print("「什麼意思？」你不解他的意思。\
        \n看著他的側臉，發現他臉上笑意更深，悲傷更深。")
        A.space()
        print("「我不知道我是不是真的快樂。」他舉起手往前伸，像是要抓住什麼，\
        \n當然什麼都沒抓住。\
        \n「我以為我誰都愛，但發現自己其實誰都不愛，更不愛我自己。」\
        \n他很溫柔，對每個人都溫柔，他以為自己是天生的溫柔，\
        \n最後才發現自己只是因為不會愛，所以對每個人都一樣溫柔。")
        A.space()
        print("「你要先學會愛你自己，才會有人愛你。」你這麼對他說。\
        \n他沒說話，許久，他才開口。\
        \n「我明白，但有時候我真的會想放棄。」他嘆氣。")
        A.space()
        print("「我很想要與世界並肩，卻發現自己跟不上世界的腳步。」他側臉看向你。\
        \n「或許我不配活在這個世界。」他說道。")
        A.space()
        print("「不要放棄。」你堅定地看著他的眼睛。\
        \n「沒有人可以定義你的成功或失敗，有時失敗何嘗不是成功的勳章？」")
        A.space()
        print("「但我做了好多好多事，總是沒有好結果。」\
        \n他細數自己所有不盡理想的沉溺，眼眸黯淡。\
        \n「這樣的我也值得繼續活在世界上嗎？」")
        A.space()
        print("「既然總是沒有好結果，那你為什麼要一再嘗試？」你反問他。")
        A.space()
        print("「因為……」他思考著。「或許是因為，我心中還有那一份對未來的憧憬吧。」")
        A.space()
        print("「那就對了。」你笑著望進他的眼瞳，笑得很溫柔。\
        \n而他愣愣被你握住手掌，強風變成的清風，撫過雙頰，風乾了淚濕的痕跡，\
        \n最終只留下在胸口不斷跳動的心臟，以及你說的那句令他心動的話。")
        A.space()
        print("「如果黑洞能吞沒一千個太陽，那你便會是那第一千零一個。」")
        A.space()
        print("你與%s的談話地點是在哪裡？(請輸入文字)" %self.name)
        s = input("回答：")
        if s == "高樓" or s == "高樓邊":
            self.favor += 40
            print(end="\n")
            print("<被%s喜歡，好感度增加>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()
        else:
            self.favor -=10
            print(end="\n")
            print("<被%s厭惡，好感度減少>" %self.name)
            print("<%s好感度變成" %self.name + str(self.favor) + ">")
            print(end="\n")
            A.drama()

    def get_info(self):
        print("<攻略角色名：%s>" %self.name)
        print("<角色好感度：%s>" %self.favor)
        print(end="\n")

    def drama(self):
        if self.favor < 60:
            print("【觸發了BE劇情，請謹慎選擇分支】")
            print(end="\n")
            print("BE大結局：")
            print(end="\n")
            print("你與%s交往多年，沒有命中注定般的相遇，也沒有轟轟烈烈的追求，\
            \n只不過是當初各自心中都有一個放不下的人，剛好遇見彼此，\
            \n各取所需，便走在了一起。" %self.name)
            A.space()
            print("本以為只要相處久了總能產生感情，可事實證明並非想像中那樣美好。\
            \n「我們分手吧。」%s這樣對你說。\
            \n「為什麼？」其實你一直擔心這一天的到來，事到臨頭，仍是不死心。\
            \n他嘆了一口氣。「這麼多年，你有在我身上用心過嗎？」\
            \n「怎麼會沒有？！」你又驚又氣，如果從沒用心，那一次次熬夜為他準備的驚喜又算什麼？" %self.name)
            A.space()
            print("「所以我說，你一點都不懂我。」%s搖搖頭，眼中剩下的只是失望。\
            \n「那些你認為對我的好，真的是我要的嗎？」\
            \n他毫不掩飾地望著你，你才忽然意識到自己好久沒有認真直視過這雙眼睛了。\
            \n「你只是把你希望我喜歡的東西給我，卻忽略我真正想要的是什麼。」\
            \n「你從沒說過。」你試圖辯駁。\
            \n「可你也從未問過。」他苦笑了一下。「這就是我們之間的問題。」" %self.name)
            print(end="\n")
            print("現在你想怎麼做？(分手/挽留)")
            be_one = input("你的選擇：")
            A.space()
            if be_one == "挽留":
                print("「難道就沒有轉圜的餘地嗎？」你對他說道。\
                \n你捨不得他。\
                \n%s是你從很久很久以前就喜歡的人，只是他不知道。\
                \n他不知道其實你心中放不下的那個人一直都是他，只有他一個人而已。" %self.name)
                A.space()
                print("你非常喜歡%s，卻不知道該怎麼與他相處，\
                \n交往這麼多年，他從沒說過，而你或許是太過安逸，也從未問過。\
                \n任由兩人之間的問題延續至今，造成傷害。\
                \n若是還有一次重來的機會，你就會知道該如何好好經營這段關係。" %self.name)
                A.space()
                print("想至此處，你聽見%s嘆了一口氣。交往這麼多年，你知道這是他心軟的樣子，於是趁勝追擊。\
                \n「再給我一次機會吧，我們之間只是缺少溝通。」你眼中有淚水，在光線下刺的心臟隱隱發疼。\
                \n時間流逝，他抿著好看的唇，眉間微蹙。\
                \n不知過了多久，才終於開口：「其實你說得也有道理，我們會走到這一步，我也不是全無責任，\
                \n如今我們既然說開了，就再相處一陣子吧。」\
                \n「嗯。」\
                \n雖然不是最好的回答，但已經足夠了。" %self.name)
                print(end="\n")
                print("<故事結束，欲知故事全貌，請選擇其他攻略路線>")
            elif be_one == "分手":
                print("「如果分手真的是你所求，那我就成全你吧。」你心中難受，卻也不願他繼續被這段關係束縛。\
                \n 你與%s在很久很久之前就見過面，當時的你心中就一直有他，\
                \n後來遇見他，直到現在，一直都沒變過。\
                \n你有多幸運才能再次與他相遇，\
                \n可是這樣的美好卻硬生生被你自己給毀了。" %self.name)
                A.space()
                print("「謝謝，我們好聚好散。」%s低下頭不再看你，語氣疏離。\
                \n而你卻因為轉身離去而忽略了他微紅的眼眶。\
                \n直到最後，你仍是沒有聽出他語氣中那一絲絲僅存的希望，\
                \n仍是不了解他。" %self.name)
                print(end="\n")
                print("<故事結束，欲知故事全貌，請選擇其他攻略路線>")
            else:
                print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
                print(end="\n")
                A.drama()

        else:
            print("【觸發了HE劇情，請謹慎選擇分支】")
            print(end="\n")
            print("HE大結局")
            print(end="\n")
            print("你與%s交往多年，是命中注定般的相遇，\
            \n才讓這個你喜歡了許多年的人再次出現在你的生命中。\
            \n再次遇見時，他正經歷情傷，你知道這是一個機會，便想辦法走進他的心。\
            \n起初他不答應，你便慌稱自己心中也有一個放不下的人，才得以接近他。\
            \n也因為這個謊言，讓他始終都認為你並不愛他。" %self.name)
            A.space()
            print("出於對%s的保護，你們之間的相處總是相敬如賓，\
            \n可以說是對彼此溫柔細膩，卻也少了戀愛的轟轟烈烈。\
            \n「你怎麼了？」這一天，你見他情緒不佳，心中疑惑，便開口問了。\
            \n「我……」他欲言又止。許久，搖搖頭。「沒事。」他說道。\
            \n「你看起來並不像沒事。」聽至此處你有些微怒，以至於將他慌忙朝你伸出的手拍開。\
            \n他那被你拍開的手僵住，眼眸中的光芒黯淡了許多。" %self.name)
            A.space()
            print("「我、我只是……」%s不知所措，眼中蒙上一層淚水，心一橫，將心中所想全盤托出。\
            \n「我知道你一直以來心中都有別人……雖然我也想過這麼長時間的相處，\
            \n或許你總有一天會愛上我，可是卻是我先愛上你。」\
            \n這是你第一次聽見他說愛你，你也才發現自己好像從未說過愛他。\
            \n「我從沒說過不愛你。」你不明白他的話是什麼意思。\
            \n「愛並不是用嘴說說而已。」他這麼說，你忽然想起剛才被自己拍開的手，以及這麼長時間的相處模式。\
            \n難怪會讓他誤會。" %self.name)
            A.space()
            print("想起過去他對你的細膩貼心、無微不至，似乎都是因為愛。\
            \n「你這個人的心，為什麼就捂不熱呢？」\
            \n淚水滑落，%s的話中藏著滿滿的愛與恨，被你聽了出來。" % self.name)
            print(end="\n")
            print("現在你想怎麼做？(隱瞞/說實話)")
            he_one = input("你的選擇：")
            print(end="\n")
            if he_one == "說實話" or he_one == "實話":
                print("你沒想到這些年的小心翼翼，竟會讓他產生這種想法，\
                \n原以為是為他著想，怕他反感所以不願與之太過親近，卻讓他產生這種念頭。\
                \n%s是你從很久很久以前就喜歡的人，只是他不知道。\
                \n他不知道其實你們早就見過面，只是你記得他，他忘了你。\
                \n事到如今，你選擇實話實說。" %self.name)
                A.space()
                print("你告訴%s，其實你心中放不下的那個人一直都是他，只有他一個人而已。\
                \n「你不要騙我了……不喜歡就不喜歡，我不會勉強你，也會放你自由。」他苦笑。\
                \n「是真的。」你直視他的雙眼，沒有一句假話。「我們甚至還能算是青梅竹馬。」" %self.name)
                A.space()
                print("%s是你小時候的鄰居，因為大人們關係很好，所以常常讓你們兩個玩在一起，\
                \n後來上了國中，他們忽然之間搬家，你並不覺得如何，全當是萍水相逢的緣分。\
                \n只是時間一久，你似乎有些懷念他，而這一絲絲懷念在心中發芽，最終長成了遺憾。\
                \n於是再次遇見，你一眼就認出了他，他與從前不同了許多，變得更加好看。\
                \n而你也長成了足夠成熟的樣子，能明白自己的心，知道自己想要什麼。" %self.name)
                A.space()
                print("「是你？」他似乎有點印象，語氣中是不敢相信。\
                \n「是我。」你嘆了口氣，伸手擁抱%s。「我等了你這麼久，終於等到你說愛我。」\
                \n「我、你……」他紅著臉，心跳如雷，不知所措。\
                \n「這些年忘記了我、還誤以為我不愛你。」你的動作不讓他繼續說下去。「你要好好補償我……」" %self.name)
                print(end="\n")
                print("<故事結束，欲知故事全貌，請選擇其他攻略路線>")
            elif he_one == "隱瞞":
                print("你沒想到這些年的小心翼翼，竟會讓他產生這種想法，\
                \n原以為是為他著想，怕他反感所以不願與之太過親近，卻讓他產生這種念頭。\
                \n%s是你從很久很久以前就喜歡的人，只是他不知道。\
                \n他不知道其實你們早就見過面，只是你記得他，他忘了你。\
                \n事到如今，你還是選擇隱瞞他，因為你心中還是隱隱期待有一天他自己想起來。" %self.name)
                A.space()
                print("你告訴%s，你心中沒有別人，一直以來愛的都只有他一個人而已。\
                \n「不要騙我，不喜歡就不喜歡，你說過你心中有別人，我也能放你回去找他。」他苦笑。\
                \n「是真的。」你想要讓他相信，你此時此刻對他的感覺。\
                \n「你能夠愛上我，那我為什麼就不能已經走出過去的傷痛，真實的愛上你呢？」\
                \n「我……」他表情微變，自知你說得有道理，雖然仍是不相信，卻有些動搖。" %self.name)
                A.space()
                print("「相信我。」你嘆了口氣，伸手擁抱%s。「我只怕你不愛我。」\
                \n懷中的他僵了僵，也嘆道：「你那麼好，我怎麼能不愛上你。」\
                \n你們把話說開，多年的心結也因為這件事情而有了解法。\
                \n相擁著，那些誤會彷彿煙消雲散。\
                \n雖然他沒想起你們曾經的過去，但是沒關係，\
                \n只要此時此刻你們相愛著便是最好的。" %self.name)
                print(end="\n")
                print("<故事結束，欲知故事全貌，請選擇其他攻略路線>")
            else:
                print("<你的選擇無法辨識，請重新閱讀，謹慎選擇！>")
                print(end="\n")
                A.drama()

#執行
print("<歡迎來到 secret date 攻略遊戲>")
print(end="\n")
A = input("攻略對象名稱：")
A = secret_date(A,30)
A.get_info()
print("【STORY START】")
print(end="\n")
A.start()
